# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.drop(columns = ['RowNumber'],inplace=True)

# %%
df.shape
# Out:
# (10000, 13)

# %%
df['CustomerId']
# Out:
# 0       15634602
# 1       15647311
# 2       15619304
# 3       15701354
# 4       15737888
#           ...
# 9995    15606229
# 9996    15569892
# 9997    15584532
# 9998    15682355
# 9999    15628319
# Name: CustomerId, Length: 10000, dtype: int64

# %%
df1 = pd.read_csv("Churn_Modelling.csv",usecols=["CustomerId","Surname","CreditScore"])

# %%
df1.shape
# Out:
# (10000, 3)

# %%
df2 = pd.read_csv("Churn_Modelling.csv",nrows=1000)

# %%
df2
# Out:
#      RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0            1    15634602    Hargrave          619    France  Female   42
# 1            2    15647311        Hill          608     Spain  Female   41
# 2            3    15619304        Onio          502    France  Female   42
# 3            4    15701354        Boni          699    France  Female   39
# 4            5    15737888    Mitchell          850     Spain  Female   43
# ..         ...         ...         ...          ...       ...     ...  ...
# 995        996    15810218         Sun          610     Spain    Male   29
# 996        997    15645621      Hunter          811     Spain    Male   44
# 997        998    15608114     Manfrin          587     Spain    Male   62
# 998        999    15659557  Artamonova          811   Germany  Female   28
# 999       1000    15787772      Hansen          759    France  Female   38
#
#      Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df.tail()
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# ...

# %%
df.sample(5)
# Out:
#       CustomerId Surname  CreditScore Geography  Gender  Age  Tenure  \
# 2201    15682435   P'eng          600    France    Male   35       4
# 6693    15665784     She          637    France    Male   27       9
# 7684    15808223     Lea          615     Spain    Male   41       1
# 7377    15592999    Reid          691    France  Female   40       0
# 4048    15653715  Coates          602    France  Female   63       7
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 2201  143744.77              2          1               0        104076.51
# 6693  128940.24              1          1               0         46786.92
# 7684  126773.43              1          1               1         55551.26
# 7377  115465.98              1          1               1         60622.61
# 4048       0.00              2          1               1         56323.21
#
#       Exited
# 2201       0
# 6693       0
# 7684       0
# 7377       0
# 4048       0

# %%
df3 = df.sample(1000)

# %%
df3
# Out:
#       CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 7314    15686670      Duke          588    France  Female   36       2
# 6509    15730590        Ko          738   Germany  Female   40       1
# 7108    15594812  Campbell          806     Spain  Female   37       2
# 8834    15794178   Walpole          657    France    Male   34       3
# 8828    15777708      Liao          824     Spain  Female   38       3
# ...          ...       ...          ...       ...     ...  ...     ...
# 7392    15795079    Nnaife          596     Spain    Male   67       6
# 3786    15728224      Kerr          710   Germany  Female   41       9
# 8376    15704657    Denman          601    France    Male   39       3
# 8285    15572631  Ndubuisi          609    France    Male   25      10
# 8613    15577018      Tsao          684   Germany  Female   26       2
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df.sample(frac=0.2)
# Out:
#       CustomerId      Surname  CreditScore Geography  Gender  Age  Tenure  \
# 6069    15810775         Tsao          576     Spain    Male   52       2
# 700     15803457          Hao          750    France  Female   32       5
# 8434    15755330       Forbes          512   Germany    Male   41       7
# 3682    15572626    Mackenzie          620     Spain    Male   44       8
# 6334    15611329      Findlay          608     Spain  Female   35       6
# ...          ...          ...          ...       ...     ...  ...     ...
# 9940    15791972  Bergamaschi          748    France  Female   20       7
# 5923    15612095    Calabrese          751    France  Female   48       9
# 1570    15607133         Shih          717     Spain  Female   49       1
# 3381    15629511   Lavrentiev          738    France    Male   49       6
# 6270    15702806       Martin          696     Spain    Male   24       9
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df.isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
m = np.random.randint(10000,size=20)

# %%
m
# Out:
# array([3552, 5611,  632,  826,  558, 7479, 1559, 5860, 9856, 2488, 3669,
#        9140, 9965,  222, 1856, 9178, 6818, 5957,  137, 1239])

# %%
df.loc[m,["Balance","Age"]] = np.nan

# %%
df.isna().sum()
# Out:
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# Age                20
# Tenure              0
# Balance            20
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited              0
# dtype: int64

# %%
df.iloc[0:100,0:5]
# Out:
#     CustomerId     Surname  CreditScore Geography  Gender
# 0     15634602    Hargrave          619    France  Female
# 1     15647311        Hill          608     Spain  Female
# 2     15619304        Onio          502    France  Female
# 3     15701354        Boni          699    France  Female
# 4     15737888    Mitchell          850     Spain  Female
# ..         ...         ...          ...       ...     ...
# 95    15699461  Fiorentini          515     Spain    Male
# 96    15738721      Graham          773     Spain    Male
# 97    15693683      Yuille          814   Germany    Male
# 98    15604348      Allard          710     Spain    Male
# 99    15633059     Fanucci          413    France    Male
#
# [100 rows x 5 columns]

# %%
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female  42.0       2
# 1       15647311       Hill          608     Spain  Female  41.0       1
# 2       15619304       Onio          502    France  Female  42.0       8
# 3       15701354       Boni          699    France  Female  39.0       1
# 4       15737888   Mitchell          850     Spain  Female  43.0       2
# ...          ...        ...          ...       ...     ...   ...     ...
# 9995    15606229   Obijiaku          771    France    Male  39.0       5
# 9996    15569892  Johnstone          516    France    Male  35.0      10
# 9997    15584532        Liu          709    France  Female  36.0       7
# 9998    15682355  Sabbatini          772   Germany    Male  42.0       3
# 9999    15628319     Walker          792    France  Female  28.0       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df.iloc[:,-2:-1]
# Out:
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4            79084.10
# ...               ...
# 9995         96270.64
# 9996        101699.77
# 9997         42085.58
# 9998         92888.52
# 9999         38190.78
#
# [10000 rows x 1 columns]

# %%
mod = df["Geography"].value_counts().index[0]

# %%
mod
# Out:
# 'France'

# %%
df["Geography"].fillna(value=mod,inplace = True)

# %%
mean = round(df["Balance"].mean(),2)

# %%
df["Balance"].fillna(value = mean,inplace = True)

# %%
df.isna().sum()
# Out:
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# Age                20
# Tenure              0
# Balance             0
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited              0
# dtype: int64

# %%
df.dropna(axis=0,how = 'any',inplace=True)

# %%
df.isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
##selecting the customer who live in fance and have churned

# %%
ans = df[(df.Geography == 'France') & (df.Exited == 1)]

# %%
ans.Geography.value_counts()
# Out:
# France    810
# Name: Geography, dtype: int64

# %%
ans
# Out:
#       CustomerId      Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0       15634602     Hargrave          619    France  Female  42.0       2
# 2       15619304         Onio          502    France  Female  42.0       8
# 35      15794171     Lombardo          475    France  Female  45.0       0
# 41      15738148       Clarke          465    France  Female  51.0       8
# 43      15755196       Lavine          834    France  Female  49.0       2
# ...          ...          ...          ...       ...     ...   ...     ...
# 9920    15673020        Smith          678    France  Female  49.0       3
# 9947    15732202   Abramovich          615    France    Male  34.0       1
# 9956    15707861        Nucci          520    France  Female  46.0      10
# 9991    15769959  Ajuluchukwu          597    France  Female  53.0       4
# 9997    15584532          Liu          709    France  Female  36.0       7
#
# ...

# %%
#ploting a histogram balance betwwen 80,000 and 1,00,000

# %%
f2 = df.query('80000<Balance<100000')

# %%
f2
# Out:
#       CustomerId         Surname  CreditScore Geography  Gender   Age  Tenure  \
# 1       15647311            Hill          608     Spain  Female  41.0       1
# 31      15706552   Odinakachukwu          533    France    Male  36.0       7
# 54      15569590             Yoo          601   Germany    Male  42.0       1
# 69      15755648          Pisano          675    France  Female  21.0       8
# 80      15706021           Buley          665    France  Female  34.0       1
# ...          ...             ...          ...       ...     ...   ...     ...
# 9956    15707861           Nucci          520    France  Female  46.0      10
# 9978    15703563           P'eng          774    France    Male  40.0       9
# 9979    15692664          Diribe          677    France  Female  58.0       1
# 9984    15696175  Echezonachukwu          602   Germany    Male  35.0       7
# 9991    15769959     Ajuluchukwu          597    France  Female  53.0       4
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
##group the row based on geography,gender combination and gives avg churned range each rows

# %%
df[["Geography","Gender","Exited"]].groupby(["Geography","Gender"]).mean()
# Out:
#                     Exited
# Geography Gender
# France    Female  0.203810
#           Male    0.127365
# Germany   Female  0.375630
#           Male    0.278751
# Spain     Female  0.211786
#           Male    0.131313

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["Balance"],range=(80000,100000))
# Out:
# (array([ 77.,  84.,  76.,  73.,  89.,  96., 106., 112., 137., 146.]),
#  array([ 80000.,  82000.,  84000.,  86000.,  88000.,  90000.,  92000.,
#          94000.,  96000.,  98000., 100000.]),
#  <BarContainer object of 10 artists>)
